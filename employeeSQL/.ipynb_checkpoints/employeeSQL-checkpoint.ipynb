# %%
# List dependencies
import pandas.io.sql as psql
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Connect to postgressql
engine=create_engine('postgresql://postgres:dso76ncs@localhost:5432/employee_db')
connection=engine.connect()

# %%
#Load the salaries table from postgres
salaries = pd.read_sql("SELECT * FROM salaries", connection)

salaries
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# Check for null values bool series True for NaN values  
bool_series = pd.isnull(salaries["salary"])

salaries[bool_series]
# Out:
# Empty DataFrame
# Columns: [emp_no, salary]
# Index: []

# %%
#Create a histogram to visualize the most common salary ranges for employees

plt.hist(salaries['salary'])

plt.xlabel('Salary Range ($)', weight='bold')
plt.ylabel('Number of Employees', weight='bold')
plt.title('Salary Range Per Employees', weight='bold')

plt.show()
plt.savefig('../images/employees_salary.png')

# %%
#Load the employees table from postgres
employees = pd.read_sql("SELECT * FROM employees", connection)

employees
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  2053-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  2054-11-18        Byong  Delgrande   F
# 2        57444        e0002  2058-01-30        Berry       Babb   F
# 3       421786        s0001  2057-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  2052-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  2058-08-14  Constantino    Eastman   M
# 300020  255832        e0002  2055-05-08       Yuping     Dayang   F
# 300021   76671        s0001  2059-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  2059-09-22        Percy   Samarati   F
# 300023  464503        s0002  2064-05-31       Arvind  Slobodova   M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# ...

# %%
employees.isnull()
# Out:
#         emp_no  emp_title_id  birth_date  first_name  last_name    sex  \
# 0        False         False       False       False      False  False
# 1        False         False       False       False      False  False
# 2        False         False       False       False      False  False
# 3        False         False       False       False      False  False
# 4        False         False       False       False      False  False
# ...        ...           ...         ...         ...        ...    ...
# 300019   False         False       False       False      False  False
# 300020   False         False       False       False      False  False
# 300021   False         False       False       False      False  False
# 300022   False         False       False       False      False  False
# 300023   False         False       False       False      False  False
#
#         hire_date
# 0           False
# 1           False
# 2           False
# 3           False
# ...

# %%
#Load the titles table from postgres
titles = pd.read_sql("SELECT * FROM titles", connection)

titles
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
titles.isnull()
# Out:
#    title_id  title
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# 5     False  False
# 6     False  False

# %%
#Merge the salaries and employees tables
salaries_employees = pd.merge(salaries, employees, on="emp_no", how="inner")
salaries_employees
# Out:
#         emp_no  salary emp_title_id  birth_date first_name last_name sex  \
# 0        10001   60117        e0003  2053-09-02     Georgi   Facello   M
# 1        10002   65828        s0001  2064-06-02    Bezalel    Simmel   F
# 2        10003   40006        e0003  2059-12-03      Parto   Bamford   M
# 3        10004   40054        e0003  2054-05-01  Chirstian   Koblick   M
# 4        10005   78228        s0001  2055-01-21    Kyoichi  Maliniak   M
# ...        ...     ...          ...         ...        ...       ...  ..
# 300019  499995   40000        e0002  2058-09-24     Dekang  Lichtner   F
# 300020  499996   58058        e0003  2053-03-07       Zito      Baaz   M
# 300021  499997   49597        e0003  2061-08-03    Berhard    Lenart   M
# 300022  499998   40000        s0001  2056-09-05   Patricia   Breugel   M
# 300023  499999   63707        e0002  2058-05-01     Sachin   Tsukuda   M
#
#          hire_date
# 0       1986-06-26
# 1       1985-11-21
# 2       1986-08-28
# ...

# %%
#Merge the salaries/employees data with the title table
salaries_titles = pd.merge(salaries_employees, titles_renamed, on="emp_title_id", how="inner")
salaries_titles
# Out:
#         emp_no  salary emp_title_id  birth_date first_name    last_name sex  \
# 0        10001   60117        e0003  2053-09-02     Georgi      Facello   M
# 1        10003   40006        e0003  2059-12-03      Parto      Bamford   M
# 2        10004   40054        e0003  2054-05-01  Chirstian      Koblick   M
# 3        10006   40000        e0003  2053-04-20     Anneke      Preusig   F
# 4        10009   60929        e0003  2052-04-19     Sumant         Peac   F
# ...        ...     ...          ...         ...        ...          ...  ..
# 300019  111534   48077        m0001  2052-06-27     Hilary       Kambil   F
# 300020  111692   40000        m0001  2054-10-05      Tonny  Butterworth   F
# 300021  111784   40000        m0001  2056-06-14      Marjo   Giarratana   F
# 300022  111877   53846        m0001  2062-10-18    Xiaobin     Spinelli   F
# 300023  111939   40000        m0001  2060-03-25    Yuchang      Weedman   M
#
#          hire_date        emp_title
# ...

# %%
#Group data by employees table and calculate the average salary
salary_by_titles=round(salaries_titles.groupby('emp_title').mean()['salary'],2)

salary_by_titles
# Out:
# emp_title
# Assistant Engineer    48564.43
# Engineer              48535.34
# Manager               51531.04
# Senior Engineer       48506.80
# Senior Staff          58550.17
# Staff                 58465.38
# Technique Leader      48582.90
# Name: salary, dtype: float64

# %%
#Create bar plot
titles_bar_chart=salary_by_titles.plot(kind="bar",title="Average Salary by Title", rot=75)

# Add the descriptive title, x labels and y labels
titles_bar_chart.set_xlabel("Titles")
titles_bar_chart.set_ylabel("Average Salary")
plt.savefig("titles_bar_chart.png")
plt.show()
